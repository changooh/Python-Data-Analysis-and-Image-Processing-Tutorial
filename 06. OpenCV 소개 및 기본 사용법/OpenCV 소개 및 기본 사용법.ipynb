# %% [markdown]
# <a href="https://colab.research.google.com/github/ndb796/Python-Data-Analysis-and-Image-Processing-Tutorial/blob/master/06.%20OpenCV%20%EC%86%8C%EA%B0%9C%20%EB%B0%8F%20%EA%B8%B0%EB%B3%B8%20%EC%82%AC%EC%9A%A9%EB%B2%95/OpenCV%20%EC%86%8C%EA%B0%9C%20%EB%B0%8F%20%EA%B8%B0%EB%B3%B8%20%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## OpenCV 소개 및 기본 사용법
# [강의 노트](https://github.com/ndb796/Python-Data-Analysis-and-Image-Processing-Tutorial/blob/master/06.%20OpenCV%20%EC%86%8C%EA%B0%9C%20%EB%B0%8F%20%EA%B8%B0%EB%B3%B8%20%EC%82%AC%EC%9A%A9%EB%B2%95/Python%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B3%BC%20%EC%9D%B4%EB%AF%B8%EC%A7%80%20%EC%B2%98%EB%A6%AC%20-%20OpenCV%20%EC%86%8C%EA%B0%9C%20%EB%B0%8F%20%EA%B8%B0%EB%B3%B8%20%EC%82%AC%EC%9A%A9%EB%B2%95.pdf)

# %% [markdown]
# CoLab에서 파일을 업로드하는 방법은 다음과 같습니다.

# %%
# from google.colab import files
# uploaded = files.upload()
# Out:
#      <input type="file" id="files-8d74f09a-1291-4b42-b73e-c79d8d625945" name="files[]" multiple disabled />
#      <output id="result-8d74f09a-1291-4b42-b73e-c79d8d625945">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg

# %% [markdown]
# ### OpenCV의 기본적인 함수
#
# * cv2.imread(file_name, flag): 이미지를 읽어 Numpy 객체로 만드는 함수
# * cv2.imshow(title, image): 특정한 이미지를 화면에 출력하는 함수
# * cv2.cvtColor(image, flag): 이미지를 색상 형태를 변경하는 함수
#
# ### CoLab에서의 이미지 출력
#
# * CoLab은 Jupyter Notebook을 기반으로 동작하므로 Matplotlib를 이용하여 이미지를 출력합니다.
# * OpenCV는 BGR을 기준으로 하며, Matplotlib는 RGB를 기준으로 합니다.

# %%
#%matplotlib inline
import cv2
import matplotlib.pyplot as plt
path = "/home/doosan04/PycharmProjects/dataAnalytics/Python-Data-Analysis-and-Image-Processing-Tutorial/images/cat.jpg"
print(path)
img_basic = cv2.imread(path, cv2.IMREAD_COLOR)
print(img_basic)
# Out:
# /home/doosan04/PycharmProjects/dataAnalytics/Python-Data-Analysis-and-Image-Processing-Tutorial/images/cat.jpg
# [[[110 129 156]
#   [101 120 147]
#   [ 87 109 134]
#   ...
#   [ 40  90 142]
#   [ 43  93 145]
#   [ 39  91 144]]
#
#  [[ 98 115 141]
#   [ 90 110 135]
#   [ 82 102 127]
#   ...
#   [ 43  93 145]
#   [ 42  95 146]
#   [ 44  96 149]]
#
#  [[ 87 103 126]
#   [ 86 103 124]
#   [ 82  99 120]
#   ...
#   [ 40  95 146]
#   [ 42  97 148]
#   [ 44  99 150]]
#
#  ...
#
#  [[113 163 183]
#   [118 165 186]
#   [124 169 190]
#   ...
#   [104 128 150]
#   [104 128 150]
#   [116 140 160]]
#
#  [[100 155 176]
#   [106 159 180]
#   [113 162 184]
#   ...
#   [101 124 146]
#   [ 96 119 141]
#   [107 128 149]]
#
#  [[ 92 151 171]
#   [ 97 154 175]
#   [108 158 180]
#   ...
#   [104 127 149]
#   [ 98 121 143]
#   [ 93 114 135]]]

# %%
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_basic = cv2.cvtColor(img_basic, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_GRAY2RGB))
plt.show()
